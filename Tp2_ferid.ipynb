# %% [markdown]
# <a href="https://colab.research.google.com/github/ferid-saad/Angular-project/blob/master/Tp2_ferid.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ***Importing libraries***

# %%
import pandas as pd  # Import pandas for data manipulation and analysis
import numpy as np  # Import NumPy for numerical operations
import matplotlib.pyplot as plt  # Import Matplotlib for data visualization

from sklearn.model_selection import train_test_split  # Function to split data into training and testing sets
from sklearn.linear_model import LinearRegression  # Import the linear regression model from scikit-learn

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ***Importing Data***

# %%
dataset= pd.read_csv('/content/drive/MyDrive/Classroom/Groupe Décembre 25/50_Startups.csv')
dataset.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
dataset.tail()
# Out:
#     R&D Spend  Administration  Marketing Spend       State    Profit
# 45    1000.23       124153.04          1903.93    New York  64926.08
# 46    1315.46       115816.21        297114.46     Florida  49490.75
# 47       0.00       135426.92             0.00  California  42559.73
# 48     542.05        51743.15             0.00    New York  35673.41
# 49       0.00       116983.80         45173.06  California  14681.40

# %% [markdown]
# ***Descriptive statiistics***

# %%
dataset.describe()
# Out:
#            R&D Spend  Administration  Marketing Spend         Profit
# count      50.000000       50.000000        50.000000      50.000000
# mean    73721.615600   121344.639600    211025.097800  112012.639200
# std     45902.256482    28017.802755    122290.310726   40306.180338
# min         0.000000    51283.140000         0.000000   14681.400000
# 25%     39936.370000   103730.875000    129300.132500   90138.902500
# 50%     73051.080000   122699.795000    212716.240000  107978.190000
# 75%    101602.800000   144842.180000    299469.085000  139765.977500
# max    165349.200000   182645.560000    471784.100000  192261.830000

# %% [markdown]
# ***Data visualization***

# %%
# Customize the plot (optional)
plt.bar(range(len(dataset['R&D Spend'])), dataset['R&D Spend'])
plt.title('Bar Chart of R&D Spend')
plt.xlabel('R&D Spend item index')
plt.ylabel('R&D Spend')
plt.show()

# %%
plt.bar(range(len(dataset['Administration'])), dataset['Administration'])
plt.title('Bar Chart of Administration')
plt.xlabel('Administration item index')
plt.ylabel('Administration')
plt.show()

# %%
plt.bar(range(len(dataset['Marketing Spend'])), dataset['Marketing Spend'])
plt.title('Bar Chart of Marketing Spend')
plt.xlabel('Marketing Spend item index')
plt.ylabel('Marketing Spend')
plt.show()

# %%
plt.scatter(dataset['R&D Spend'], dataset.Profit, marker='o')
plt.title('Scatterplot of R&D Spend vs.Profit')
plt.xlabel('R&D Spend')
plt.ylabel('Profit')
plt.show()

# %%
plt.scatter(dataset['Administration'], dataset.Profit, marker='o')
plt.title('Scatterplot of Administration vs.Profit')
plt.xlabel('Administration')
plt.ylabel('Administration')
plt.show()

# %%
plt.scatter(dataset['Marketing Spend'], dataset.Profit, marker='o')
plt.title('Scatterplot of Marketing Spend vs.Profit')
plt.xlabel('Marketing Spend')
plt.ylabel('Profit')
plt.show()

# %% [markdown]
# ***Data Processing***

# %%
# Checking the shape of the data
dataset.shape
# Out:
# (50, 5)

# %%
# Unique values in each colum
dataset.nunique()
# Out:
# R&D Spend          49
# Administration     50
# Marketing Spend    48
# State               3
# Profit             50
# dtype: int64
